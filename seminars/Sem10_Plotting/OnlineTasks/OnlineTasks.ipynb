# %%
import pandas
import seaborn

# %% [markdown]
# # Задача №63:
# 1. Изобразите отношение `households` к `population` с помощью точечного графика
# 2. Визуализировать `longitude` по отношения к `median_house_value`, используя линейный график
# 3. Представить `гистограмму` по `housing_median_age`
# 4. Изобразить гистограмму по `median_house_value` с оттенком `housing_median_age`

# %%
data_frame = pandas.read_csv('/Users/unknownman/Library/CloudStorage/OneDrive-Личная/GeekBrains/Faculty-Software_Engineer_(Python)/Second_quater/1-Introduction_to_Python/seminars/Sem10_Plotting/source/california_housing_train.csv')
data_frame.head(n=5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -114.31     34.19                15.0       5612.0          1283.0  \
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
seaborn.scatterplot(data=data_frame, x='households', y='population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
seaborn.relplot(data=data_frame, x='longitude', y='median_house_value',kind='line')

# %%
seaborn.histplot(data=data_frame, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
seaborn.histplot(data=data_frame, x='median_house_value', hue='housing_median_age', legend='brief')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# # Задача №65:
# Написать EDA для датасета про пингвинов Необходимо:
# - Использовать 2-3 точечных графика
# - Применить доп измерение в точечных графиках, используя аргументы `hue`, `size`, `stile`
# - Использовать `PairGrid` с типом графика на ваш выбор
# - Изобразить `heatmap`
# - Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
# ```Python
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %%
penguins = pandas.read_csv('/Users/unknownman/Library/CloudStorage/OneDrive-Личная/GeekBrains/Faculty-Software_Engineer_(Python)/Second_quater/1-Introduction_to_Python/seminars/Sem10_Plotting/source/seaborn_penguins.csv')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0  Adelie  Torgersen            39.1           18.7              181.0  \
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
seaborn.scatterplot(penguins, x='body_mass_g', y='flipper_length_mm', hue='species', style='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
seaborn.scatterplot(penguins, x='body_mass_g', y='bill_depth_mm', size='bill_length_mm', hue='species', style='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
seaborn.scatterplot(penguins, x='body_mass_g', y='bill_length_mm', size='bill_depth_mm', hue='species', style='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
seaborn.scatterplot(penguins, x='flipper_length_mm', y='bill_depth_mm', size='bill_length_mm', hue='species', style='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
seaborn.scatterplot(penguins, x='flipper_length_mm', y='bill_length_mm', hue='species', size='island', style='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
seaborn.scatterplot(penguins, x='flipper_length_mm', y='bill_length_mm', hue='species', size='island', style='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
columns = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
pair_grid = seaborn.PairGrid(penguins[columns])
pair_grid.map(seaborn.scatterplot)

# %%
seaborn.heatmap(penguins[columns])
# Out:
# <Axes: >

# %%
seaborn.histplot(penguins, x='bill_length_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='bill_length_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='bill_length_mm', hue='island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='bill_depth_mm', hue='island')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='bill_depth_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='flipper_length_mm', hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='flipper_length_mm', hue='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='body_mass_g', hue='island')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='body_mass_g', hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# # Задача №67:
# Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина.
# - `high` - длинный(от 42)
# - `middle` - средний(от 35 до 42)
# - `low` - маленький(до 35)
#
# Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
# ```Python
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %%
penguins.loc[42 <= penguins['bill_length_mm'], ['bill_group']] = 'high'
penguins.loc[(35 <= penguins['bill_length_mm']) & (penguins['bill_length_mm'] < 42), ['bill_group']] ='middle'
penguins.loc[penguins['bill_length_mm'] < 35, ['bill_group']] = 'low'
penguins.head(n=5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0  Adelie  Torgersen            39.1           18.7              181.0  \
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex bill_group
# 0       3750.0    MALE     middle
# 1       3800.0  FEMALE     middle
# 2       3250.0  FEMALE     middle
# 3          NaN     NaN        NaN
# 4       3450.0  FEMALE     middle

# %% [markdown]
# # Задача №69:
# Изобразить гистограмму по `flipper_length_mm` с оттенком `height_group`. Сделать анализ

# %%
seaborn.histplot(penguins, x='flipper_length_mm', hue='bill_group')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
seaborn.histplot(penguins, x='species', hue='bill_group')
# Out:
# <Axes: xlabel='species', ylabel='Count'>
